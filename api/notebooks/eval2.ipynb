# %%
import os
import sys

module_path = os.path.abspath(os.path.join('../srdt/api/'))
if module_path not in sys.path:
    sys.path.append(module_path)


import pandas as pd
from srdt_analysis.collections import AlbertCollectionHandler
from srdt_analysis.legi_data import get_legi_data

# %load_ext dotenv
#%reload_ext dotenv
# %dotenv

# %%
# read questions
questions = pd.read_csv("/Users/remi/Downloads/questions_v2.csv", index_col="id")

# custom hack
questions.loc[9]['question'] = questions.loc[9]['question'].lower().replace(" ij ", " indemnité journalière ")
questions.loc[16]['question'] = questions.loc[16]['question'].lower().replace(" cp ", " congés payés ")
# Out:
# /var/folders/y9/zlln1xg565d8w1d8btf1c1b00000gn/T/ipykernel_31364/3675195285.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   questions.loc[9]['question'] = questions.loc[9]['question'].lower().replace(" ij ", " indemnité journalière ")
# /var/folders/y9/zlln1xg565d8w1d8btf1c1b00000gn/T/ipykernel_31364/3675195285.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   questions.loc[16]['question'] = questions.loc[16]['question'].lower().replace(" cp ", " congés payés ")

# %%
# read labels
labels = pd.read_csv("/Users/remi/Downloads/search_eval2.csv")
labels = labels[labels['valid'] == 1]
labels
# Out:
#     question                                               link positive  \
# 0          6  https://code.travail.gouv.fr/fiche-service-pub...        T
# 2          6  https://code.travail.gouv.fr/fiche-ministere-t...        T
# 4          6  https://code.travail.gouv.fr/fiche-ministere-t...        T
# 5          6  https://code.travail.gouv.fr/fiche-ministere-t...        T
# 6          8  https://code.travail.gouv.fr/fiche-service-pub...        T
# 7          8  https://code.travail.gouv.fr/fiche-service-pub...        T
# 8          8  https://code.travail.gouv.fr/fiche-ministere-t...        T
# 12         8  https://code.travail.gouv.fr/fiche-service-pub...        T
# 13         8  https://code.travail.gouv.fr/fiche-service-pub...        T
# 14         8  https://code.travail.gouv.fr/fiche-service-pub...        T
# 15         8  https://code.travail.gouv.fr/fiche-service-pub...        T
# 16         8  https://code.travail.gouv.fr/fiche-ministere-t...        T
# 17         8  https://code.travail.gouv.fr/fiche-ministere-t...        T
# 18         8  https://code.travail.gouv.fr/fiche-ministere-t...        T
# 19         8  https://code.travail.gouv.fr/fiche-ministere-t...        T
# 20         8  https://code.travail.gouv.fr/fiche-ministere-t...        T
# 21         8  https://code.travail.gouv.fr/fiche-ministere-t...        T
# 22         8  https://code.travail.gouv.fr/fiche-ministere-t...        T
# 23        11  https://code.travail.gouv.fr/fiche-service-pub...        T
# 24        11  https://code.travail.gouv.fr/fiche-ministere-t...        T
# 25        11  https://code.travail.gouv.fr/fiche-service-pub...        T
# 27        11  https://code.travail.gouv.fr/fiche-ministere-t...        T
# 28        14  https://code.travail.gouv.fr/fiche-ministere-t...        T
# 34        14  https://code.travail.gouv.fr/fiche-service-pub...        T
# 35        15  https://code.travail.gouv.fr/fiche-service-pub...        T
# 36        15  https://code.travail.gouv.fr/fiche-service-pub...        T
# 37        15  https://code.travail.gouv.fr/fiche-ministere-t...        T
# 38        15  https://code.travail.gouv.fr/contribution/est-...        T
# 39        15  https://code.travail.gouv.fr/fiche-service-pub...        T
#
#     valid source
# 0       1    NaN
# 2       1    NaN
# 4       1    NaN
# 5       1    NaN
# 6       1    NaN
# 7       1    NaN
# 8       1    NaN
# 12      1    NaN
# 13      1    NaN
# 14      1    NaN
# 15      1    NaN
# 16      1    NaN
# 17      1    NaN
# 18      1    NaN
# 19      1    NaN
# 20      1    NaN
# 21      1    NaN
# 22      1    NaN
# 23      1    NaN
# 24      1    NaN
# 25      1    NaN
# 27      1    NaN
# 28      1    NaN
# 34      1    NaN
# 35      1    NaN
# 36      1    NaN
# 37      1    NaN
# 38      1    NaN
# 39      1    NaN

# %%
collections = AlbertCollectionHandler()

# %%
# load data
docs = pd.read_parquet("/Users/remi/tmp/docs.parquet")
chunks = pd.read_parquet("/Users/remi/tmp/chunks.parquet")

# code 
code = get_legi_data()

# %%
all_paths = docs['url'].to_list()

# %%
user_question = "Bonjour,  J’ai effectuée un remplacement en CDD dans une micro crèche, mon contrat étant fini depuis le 22 septembre 2023 je suis toujours en attente de mon salaire. Après plusieurs relance auprès de la directrice aucun versement n’a été fait. J’aimerais savoir si elle est en droit de me faire patienter comme cela ou sinon qu’elle sont les délais pour qu’elle puisse me verser mon salaire. Cordialement"

contributions_col = 733
info_col = 734
fiche_sp_col = 738
fiche_mt_col = 735

res_search = collections.search(user_question, [contributions_col, info_col, fiche_mt_col, fiche_sp_col], 64)

len(res_search)
# Out:
# 64

# %%
def to_row(chunk, in_results: bool, in_positives: bool):
    link = chunk['metadata']['url']
    content = chunk['content']
    score = f'{chunk['score']:.2f}'  
    in_dataset = 1 if link in all_paths else 0
    original_id = docs[docs['url'] == link]['cdtn_id'] if in_dataset == 1 else 'n/a'
    
    return {"element": link, "in_results": in_results, "in_positives": in_positives, "in_dataset": in_dataset, "score": score, "content" : content, "url": link, "original_id": original_id}

async def analyze_question(id: int):
    content = questions.loc[id]['question']
    print(content)

    positives = labels[(labels["question"] == id) & (labels["positive"] == 'T') ]['link']

    
    #res = search_bm25(content)
    
    #res = collections.search(content, [contributions_col, info_col, fiche_mt_col, fiche_sp_col], 128)

    res = combined_search(content)    

    # merge chunks (warning it could be too long!)
    chunks = {}
    for r in res:
        chunk = r['chunk']
        chunk['score'] = r['score']
        # temp fix
        chunk['metadata']['url'] = chunk['metadata']['url'].replace('contributions/', 'contribution/')
        
        url = chunk['metadata']['url']
        elem = url
        if (elem not in chunks):
            chunks[elem] = chunk
        else :
            #print(elem)
            chunks[elem]['content'] = "\n\n".join([chunks[elem]['content'], chunk['content']])
            
    search_res = chunks.values()
    
    #print(search_res)
    

    
    emptyness = pd.Series(None, dtype=int)
    results_df = pd.DataFrame(to_row(sr, 1, 0) for sr in search_res) if len(search_res) > 0 else  pd.DataFrame({"url":[], "element":[], "in_results": emptyness, "in_positives":emptyness})

    missing=[]
    
    for p in positives:
        index = [results_df.index[results_df['url'] == p]][0]
        if len(index):
            results_df.at[index[0], 'in_positives'] = 1
        else:
            missing.append(p)


    inputs = [c['content'][:8192] for c in search_res][:64]
    reranked = collections.rerank(content, inputs)
    
    rr_indices = pd.Series({r["index"]: i for i,r in enumerate(reranked)})

    results_df["rr_score"] = pd.Series({r["index"]: r["score"] for i, r in enumerate(reranked)})

    results_df["reranked"] = rr_indices
    
    results_df = pd.concat([results_df, pd.DataFrame([to_row({"content":docs[docs['url'] == m]['content_chunked'] if m in all_paths else "n/a", "score":0, "metadata":{"url":m}}, 0,1) for m in missing])], ignore_index=True)  

    results_df.sort_values(by='reranked', inplace=True)
    
    return results_df

# %%
with pd.option_context('display.width', 500, 'display.max_rows', 200, 'display.max_colwidth', 200):
    # 6 8 11 14 15
    response = await analyze_question(14)
    display(response)
# Out:
# Quelle est la procdure suivre pour demander une dérogation pour que mes techniciens puissent ponctuellement travailler 60 heures par semaine pour un chantier particulier?
#
# Cest dire rajouter la journée du samedi au reste de la semaine.
#                                                                                                                                                                                                element  in_results  in_positives  in_dataset score                                                                                                                                                                                                  content  \
# 13                                                                                                                     https://code.travail.gouv.fr/fiche-ministere-travail/la-duree-legale-du-travail           1             1           1  0.02  En matière de durée du travail, la réglementation définit précisément les règles applicables et les possibilités d'adaptation ouvertes par la négociation collective. \nCette matière est ...
# 10                                                                                              https://code.travail.gouv.fr/fiche-ministere-travail/le-temps-de-travail-des-jeunes-de-moins-de-18-ans           1             0           1  0.02  À savoir ! La durée du travail du mineur de 14 à moins de 16 ans travaillant pendant ses vacances scolaires ne peut excéder 35 heures par semaine, ni 7 heures par jour. \nLa durée du travail ...
# 8                                                                                                      https://code.travail.gouv.fr/fiche-service-public/duree-du-travail-dun-jeune-de-moins-de-18-ans           1             0           1  0.03  Quelle est la durée de temps de travail autorisée d'un salarié de moins de 18 ans ? Le salarié bénéficie-t-il de dispositions spécifiques ? Nous vous présentons la réglementation en vigue...
# 3                                                                                                         https://code.travail.gouv.fr/fiche-service-public/duree-du-travail-dun-salarie-a-temps-plein           1             1           1  0.03  Combien d'heures de travail pouvez-vous effectuer par jour, par semaine, par mois et par an ? Est-il possible de travailler plus longtemps que la durée légale le prévoit ? Nous vous expliquons ...
# 27                                                                                                                             https://code.travail.gouv.fr/fiche-ministere-travail/le-travail-de-nuit           1             0           1  0.02  Selon Santé publique France, le travail de nuit pris en globalité en considérant le travail de nuit habituel et occasionnel, concerne 4,3 millions de personnes en France. \nMais quelle est pré...
# 1                                                                                                    https://code.travail.gouv.fr/fiche-service-public/temps-partiel-dun-salarie-dans-le-secteur-prive           1             0           1  0.03  Quelle est la durée d'un travail à temps partiel ? Un salarié est à temps partiel lorsqu'il travaille pendant une durée inférieure à celle d'un salarié à temps plein. La durée minimale d...
# 12                                                                                        https://code.travail.gouv.fr/fiche-ministere-travail/le-travail-a-temps-partiel-contrat-et-statut-du-salarie           1             0           1  0.02  À savoir ! \nUne exonération de cotisations salariales s'applique au titre des heures complémentaires (et supplémentaires pour les salariés à temps plein) effectuées par les salariés (plus...
# 21                                                                                                  https://code.travail.gouv.fr/fiche-service-public/travail-le-dimanche-dun-salarie-du-secteur-prive           1             0           1  0.02  Un salarié peut-il être contraint de travailler le dimanche ? Le dimanche est, en principe, une journée légale de repos. Mais des exceptions existent. On parle alors de dérogation au repos do...
# 49                                                                                                       https://code.travail.gouv.fr/fiche-service-public/travail-de-nuit-du-salarie-du-secteur-prive           1             0           1  0.01  Le travail de nuit est justifié par la nécessité d'assurer la continuité de l'activité de l'entreprise. Il doit être exceptionnel. L'employeur peut dans ce cas faire travailler les salariés...
# 4                                                                                               https://code.travail.gouv.fr/fiche-service-public/temps-de-travail-du-salarie-amenagement-des-horaires           1             0           1  0.03  Si l'entreprise alterne périodes de haute et de basse activité, elle peut prévoir un aménagement du temps de travail des salariés. Durant cette période, le salarié peut être amené à trav...
# 17                                                                                                             https://code.travail.gouv.fr/fiche-service-public/embauche-en-contrat-dextra-cdd-dusage           1             0           1  0.02  Pouvez-vous conclure avec votre employeur un contrat d'extra (également dénommé CDD d'usage) ? Dans quelles conditions ce type de contrat peut-il être mis en place ? Quels sont les secteurs d'...
# 38                                                                                                       https://code.travail.gouv.fr/fiche-ministere-travail/les-heures-supplementaires-contreparties           1             0           1  0.01  À savoir Une exonération de cotisations salariales est appliquée au titre des heures supplémentaires (et complémentaires pour les salariés à temps partiel) effectuées par les salariés (pl...
# 14                                                                                               https://code.travail.gouv.fr/fiche-service-public/heures-supplementaires-dun-salarie-du-secteur-prive           1             0           1  0.02  Qu'est-ce qu'une heure supplémentaire ? Le salarié est-il libre d'effectuer des heures supplémentaires et comment lui sont-elles payées ? Nous vous présentons le dispositif selon que vous tra...
# 23                                                                                               https://code.travail.gouv.fr/fiche-service-public/temps-de-travail-du-salarie-horaires-individualises           1             0           1  0.02  Le salarié peut-il bénéficier d'un aménagement personnalisé de ses horaires de travail ? L'employeur peut-il refuser la demande du salarié ? Nous vous présentons les informations à connaî...
# 57                                                                                                                       https://code.travail.gouv.fr/fiche-ministere-travail/la-journee-de-solidarite           1             0           1  0.01  À savoir ! S’agissant des règles applicables à la Journée de solidarité, il convient de distinguer les domaines relevant de l’ordre public, c’est-à-dire ceux pour lesquels le législateur fi...
# 50                                                                                             https://code.travail.gouv.fr/fiche-service-public/paye-du-salarie-a-domicile-employe-par-un-particulier           1             0           1  0.01  La paye du salarié employé à domicile par un particulier est composée d'un salaire de base et d'éventuels éléments accessoires. La rémunération des heures supplémentaires, des jours fér...
# 61                                                                                             https://code.travail.gouv.fr/fiche-ministere-travail/aide-a-la-garde-denfants-pour-parents-isoles-agepi           1             0           1  0.01  À savoir \nL’AGE n’est soumise ni à cotisations sociales, ni à l’impôt sur le revenu. Elle est, le cas échéant, cessible et saisissable. \nL’AGE peut être accordée : \nÀ un demandeur d’em...
# 55                                                                                                                     https://code.travail.gouv.fr/contribution/embauche-en-contrat-dextra-cdd-dusage           1             0           1  0.01  Le recours à un contrat d'extra (CDD d'usage) est encadré par certaines règles. \nLe contrat d'extra ou contrat d'usage est un CDD particulier qui permet à un employeur d’embaucher un salarié...
# 56                                                                                          https://code.travail.gouv.fr/fiche-service-public/combien-dheures-un-salarie-peut-il-travailler-en-continu           1             0           1  0.01  Le nombre d'heures de travail qu'un salarié peut effectuer en continu dépend du secteur d'activité dans lequel il travaille. Cas général Un salarié ne doit pas travailler plus de 6 heures de...
# 20                                                                                        https://code.travail.gouv.fr/fiche-service-public/particulier-employeur-conges-du-salarie-employe-a-domicile           1             0           1  0.02  Le salarié employé à domicile par un particulier a droit à des congés dans les mêmes conditions que tout autre salarié. Toutefois, certaines règles spécifiques sont fixées par la convent...
# 26                                                                                     https://code.travail.gouv.fr/fiche-service-public/licenciement-du-salarie-a-domicile-employe-par-un-particulier           1             0           1  0.02  Lorsqu'un particulier employeur envisage de licencier un salarié à domicile embauché en CDI , il doit le convoquer à un entretien préalable et lui envoyer une lettre de licenciement . Certain...
# 59                                                                           https://code.travail.gouv.fr/fiche-service-public/jour-ouvrable-jour-ouvre-jour-franc-jour-calendaire-quelles-differences           1             0           1  0.01  Qu'est-ce qu'un jour ouvrable ? Un jour ouvrable correspond à tous les jours de la semaine qui peuvent être légalement travaillés, à l'exception du jour de repos hebdomadaire (généralement ...
# 46                                                                                                                                                https://code.travail.gouv.fr/code-du-travail/r3162-1           1             0           1  0.01  Lorsque l'organisation collective du travail le justifie, en application de l'article L. 3162-1 , les jeunes travailleurs peuvent être employés à un travail effectif excédant huit heures par j...
# 54                                                                                                              https://code.travail.gouv.fr/fiche-ministere-travail/accords-de-performance-collective           1             0           1  0.01  À noter : Le dispositif des accords de performance collective, prévu par l’article L. 2254-2 du Code du travail, prend la suite, notamment, des accords de maintien de l’emploi, et des accords de...
# 36                                                                                                           https://code.travail.gouv.fr/fiche-service-public/a-partir-de-quel-age-peut-on-travailler           1             0           1  0.01  Il est possible de travailler dès l'âge de 16 ans, quel que soit le type de contrat ( CDI , CDD , contrat temporaire). Tout mineur doit y être autorisé par son représentant légal (père ou m...
# 60                                                                                                    https://code.travail.gouv.fr/fiche-service-public/modification-du-contrat-de-travail-dun-salarie           1             0           1  0.01  Un salarié peut-il refuser les modifications de son contrat de travail envisagées par son employeur ? Nous vous expliquons la réglementation en vigueur, selon que le contrat de travail est modi...
# 62                                                                                                             https://code.travail.gouv.fr/fiche-ministere-travail/job-dete-formalites-et-obligations           1             0           1  0.01  À savoir Avant d’embaucher un jeune âgé de 14 à 16 ans, l’employeur doit demander à l’inspecteur du travail une autorisation de recruter. Dès lors qu'ils ont plus de 14 ans, tous les jeunes ...
# 33                                                                                 https://code.travail.gouv.fr/fiche-service-public/a-quelles-conditions-un-salarie-peut-il-cumuler-plusieurs-emplois           1             0           1  0.01  Oui, vous pouvez cumuler plusieurs emplois mais sous certaines conditions. Nous vous expliquons les conditions de cumul selon votre situation : Vous cumulez des activités salariées Conditions de...
# 37                                                                                    https://code.travail.gouv.fr/fiche-service-public/compte-personnel-de-formation-cpf-dun-salarie-du-secteur-prive           1             0           1  0.01  Vous souhaitez suivre une formation pour évoluer professionnellement ? Sachez que toute personne dispose, dès son entrée sur le marché du travail et jusqu'à son départ à la retraite, d'un c...
# 6                                                                                                              https://code.travail.gouv.fr/contribution/quelles-sont-les-conditions-de-cumul-demplois           1             0           1  0.03  Il est possible de cumuler plusieurs emplois mais sous certaines conditions : \nConditions de cumul d'emploi \nIl est possible de cumuler plusieurs emplois si le salarié répond à toutes les con...
# 95                                                                                                                                                https://code.travail.gouv.fr/code-du-travail/l3134-3           1             0           1  0.01  Dans les exploitations de mines, salines et carrières, établissements industriels, chantiers du bâtiment et du génie civil, chantiers navals, le repos donné aux salariés est de : 1° Vingt-qu...
# 96                                                            https://code.travail.gouv.fr/fiche-service-public/le-particulier-employeur-peut-il-modifier-le-contrat-de-travail-dun-salarie-a-domicile           1             0           1  0.01  Le particulier employeur qui embauche un salarié à son domicile doit en principe rédiger un contrat de travail écrit. Lorsque les relations de travail évoluent, l'employeur peut proposer au s...
# 97                                                                          https://code.travail.gouv.fr/fiche-service-public/quelles-sont-les-incidences-du-chomage-partiel-sur-le-contrat-de-travail           1             0           1  0.01  L’activité partielle est un dispositif qui permet à l’employeur en difficulté de faire prendre en charge par l'État tout ou partie du coût de la rémunération du salarié. Le contrat de trav...
# 98                                                                                   https://code.travail.gouv.fr/fiche-service-public/etudiant-etranger-comment-travailler-en-france-apres-ses-etudes           1             0           1  0.01  Vous êtes un étudiant étranger et souhaitez travailler en France à la fin de vos études supérieures ? Vous pouvez prétendre à différents titres de séjour. Les règles diffèrent en fonct...
# 99                                                                         https://code.travail.gouv.fr/fiche-service-public/labsence-du-salarie-est-elle-prise-en-compte-pour-le-calcul-de-ses-conges           1             0           1  0.01  Oui, certaines périodes d'absence permettent tout de même au salarié d'acquérir des congés payés si ces absences sont assimilées à du temps de travail effectif . Dès lors, ces périodes d...
# 100                                                                               https://code.travail.gouv.fr/fiche-service-public/carte-btp-carte-didentification-professionnelle-dun-salarie-du-btp           1             0           1  0.01  Sur un chantier de bâtiment ou de travaux publics, la réalisation de certains travaux impose au salarié de détenir une carte d'identification professionnelle. L'employeur est responsable de la...
# 101                                                                                                                                              https://code.travail.gouv.fr/code-du-travail/r4532-82           1             0           1  0.01  Ne sont pas tenues de participer aux travaux du collège interentreprises les entreprises dont il est prévu qu'elles n'occuperont pas sur le chantier au moins dix travailleurs pendant au moins qu...
# 102                                                                             https://code.travail.gouv.fr/fiche-service-public/quelle-obligation-pour-lemployeur-en-matiere-de-complementaire-sante           1             0           1  0.01  Tout employeur du secteur privé (entreprise et association) a l'obligation de proposer une couverture complémentaire santé collective à ses salariés, sauf exceptions. Cette couverture peut ê...
# 103                                                              https://code.travail.gouv.fr/fiche-service-public/don-de-jours-de-repos-a-un-salarie-parent-denfant-gravement-malade-ou-proche-aidant           1             0           1  0.01  Pouvez-vous, renoncer à tout ou partie de vos jours de repos non pris au profit d'un collègue de travail dont un enfant est gravement malade ou d'un collègue proche aidant ? Nous faisons un poi...
# 104                                                                                                                                  https://code.travail.gouv.fr/fiche-service-public/salarie-au-pair           1             0           1  0.01  Qui peut être salarié au pair ? Quelles démarches doit effectuer le particulier employeur ? Quelle est la protection sociale du salarié au pair ? Nous faisons le point sur la réglementation. ...
# ...
# 91                                                                                    https://code.travail.gouv.fr/fiche-service-public/un-particulier-employeur-peut-il-embaucher-un-salarie-etranger  13369    9b240ddc20
# Name: cdtn_id, dtype: object       NaN       NaN
# 92                                                                                   https://code.travail.gouv.fr/fiche-service-public/arret-maladie-pendant-la-periode-dessai-quelles-sont-les-regles  13189    5de46d44b2
# Name: cdtn_id, dtype: object       NaN       NaN
# 93                                                                                                                           https://code.travail.gouv.fr/fiche-ministere-travail/le-travail-en-soiree   1393    6e11f3e838
# Name: cdtn_id, dtype: object       NaN       NaN
# 94                                                                                                                                                https://code.travail.gouv.fr/code-du-travail/l3162-1   9422    8fe729beb6
# Name: cdtn_id, dtype: object       NaN       NaN
# 95                                                                                                                                                https://code.travail.gouv.fr/code-du-travail/l3134-3   9032    39d04da9ad
# Name: cdtn_id, dtype: object       NaN       NaN
# 96                                                            https://code.travail.gouv.fr/fiche-service-public/le-particulier-employeur-peut-il-modifier-le-contrat-de-travail-dun-salarie-a-domicile  13093    6d8dbe2da3
# Name: cdtn_id, dtype: object       NaN       NaN
# 97                                                                          https://code.travail.gouv.fr/fiche-service-public/quelles-sont-les-incidences-du-chomage-partiel-sur-le-contrat-de-travail  13506    aa3775f94a
# Name: cdtn_id, dtype: object       NaN       NaN
# 98                                                                                   https://code.travail.gouv.fr/fiche-service-public/etudiant-etranger-comment-travailler-en-france-apres-ses-etudes  13154    c32ea4e3d9
# Name: cdtn_id, dtype: object       NaN       NaN
# 99                                                                         https://code.travail.gouv.fr/fiche-service-public/labsence-du-salarie-est-elle-prise-en-compte-pour-le-calcul-de-ses-conges  13545    3e5317d31a
# Name: cdtn_id, dtype: object       NaN       NaN
# 100                                                                               https://code.travail.gouv.fr/fiche-service-public/carte-btp-carte-didentification-professionnelle-dun-salarie-du-btp  13407    1bfbf4186f
# Name: cdtn_id, dtype: object       NaN       NaN
# 101                                                                                                                                              https://code.travail.gouv.fr/code-du-travail/r4532-82   8139    cd0b0bb8b4
# Name: cdtn_id, dtype: object       NaN       NaN
# 102                                                                             https://code.travail.gouv.fr/fiche-service-public/quelle-obligation-pour-lemployeur-en-matiere-de-complementaire-sante  13237    d4fe3d0a4b
# Name: cdtn_id, dtype: object       NaN       NaN
# 103                                                              https://code.travail.gouv.fr/fiche-service-public/don-de-jours-de-repos-a-un-salarie-parent-denfant-gravement-malade-ou-proche-aidant  13259    4b91cb9140
# Name: cdtn_id, dtype: object       NaN       NaN
# 104                                                                                                                                  https://code.travail.gouv.fr/fiche-service-public/salarie-au-pair  13338    a577b03868
# Name: cdtn_id, dtype: object       NaN       NaN
# 105                                                                                                                                              https://code.travail.gouv.fr/code-du-travail/l3121-23  10567    6689a04369
# Name: cdtn_id, dtype: object       NaN       NaN
# 106                                                                              https://code.travail.gouv.fr/fiche-service-public/absence-dun-salarie-pour-cause-dintemperies-quelles-sont-les-regles  13144    bc7340b2be
# Name: cdtn_id, dtype: object       NaN       NaN
# 107                                                                                             https://code.travail.gouv.fr/fiche-service-public/licenciement-protection-du-representant-du-personnel  13102    d6d903bbcd
# Name: cdtn_id, dtype: object       NaN       NaN
# 108                                                                                                                https://code.travail.gouv.fr/fiche-service-public/comment-sinformer-sur-sa-retraite  13464    2a2beff57c
# Name: cdtn_id, dtype: object       NaN       NaN
# 109                                                                                                   https://code.travail.gouv.fr/fiche-service-public/procedure-de-licenciement-pour-motif-personnel  13444    3fc2707973
# Name: cdtn_id, dtype: object       NaN       NaN
# 110                                                                                                      https://code.travail.gouv.fr/fiche-service-public/jours-feries-et-ponts-dans-le-secteur-prive  13120    99552cd4ab
# Name: cdtn_id, dtype: object       NaN       NaN
# 111                                                                        https://code.travail.gouv.fr/fiche-service-public/salarie-au-domicile-de-lemployeur-que-faire-en-cas-de-deces-de-lemployeur  13170    318607cec1
# Name: cdtn_id, dtype: object       NaN       NaN
# 112                                                                                        https://code.travail.gouv.fr/fiche-service-public/comment-faire-sa-demande-de-retraite-lorsquon-est-salarie  13457    482c932f87
# Name: cdtn_id, dtype: object       NaN       NaN
# 113                                                                                         https://code.travail.gouv.fr/fiche-ministere-travail/questions-reponses-activite-partielle-chomage-partiel   1433    e9d3b1b1d7
# Name: cdtn_id, dtype: object       NaN       NaN
# 114                                                                                                            https://code.travail.gouv.fr/fiche-ministere-travail/activite-partielle-chomage-partiel   1434    587080948b
# Name: cdtn_id, dtype: object       NaN       NaN
# 115                                                                                                        https://code.travail.gouv.fr/fiche-service-public/heures-dequivalence-dans-le-secteur-prive  13438    3ff00f4eb9
# Name: cdtn_id, dtype: object       NaN       NaN
# 116                                                                                  https://code.travail.gouv.fr/fiche-service-public/declaration-dactivite-des-formateurs-ou-organismes-de-formation  13355    14427b3d0a
# Name: cdtn_id, dtype: object       NaN       NaN
# 117                                                                                                                          https://code.travail.gouv.fr/fiche-service-public/preavis-de-licenciement  13246    76ca07e805
# Name: cdtn_id, dtype: object       NaN       NaN
# 118                                                                                                      https://code.travail.gouv.fr/fiche-service-public/licenciement-economique-entretien-prealable  13419    91095d1f44
# Name: cdtn_id, dtype: object       NaN       NaN
# 119                                                                                                                                               https://code.travail.gouv.fr/code-du-travail/l3123-6   6977    d00b0d718c
# Name: cdtn_id, dtype: object       NaN       NaN
# 120                                                                                         https://code.travail.gouv.fr/fiche-service-public/resiliation-judiciaire-du-contrat-de-travail-dun-salarie  13351    4b5bea71db
# Name: cdtn_id, dtype: object       NaN       NaN
# 121                                                            https://code.travail.gouv.fr/fiche-service-public/hospitalisation-du-nouveau-ne-quelles-sont-les-consequences-sur-le-conge-de-maternite  13162    f25f92dafb
# Name: cdtn_id, dtype: object       NaN       NaN
# 122                                                                                                                                              https://code.travail.gouv.fr/code-du-travail/l1221-25  10010    6c495223dc
# Name: cdtn_id, dtype: object       NaN       NaN
# 123                                                                                                                                               https://code.travail.gouv.fr/code-du-travail/r1332-3   9905    8e91ecc8e3
# Name: cdtn_id, dtype: object       NaN       NaN
# 124                                                                                               https://code.travail.gouv.fr/fiche-service-public/retraite-anticipee-pour-carriere-longue-du-salarie  13209    adbf450f77
# Name: cdtn_id, dtype: object       NaN       NaN
# 125                                                                                                      https://code.travail.gouv.fr/fiche-service-public/droit-de-greve-dun-salarie-du-secteur-prive  13135    34c00ffd38
# Name: cdtn_id, dtype: object       NaN       NaN
# 126                                                                        https://code.travail.gouv.fr/fiche-service-public/particulier-employeur-a-quoi-sert-le-cesu-declaratif-et-comment-y-adherer  13334    c9d23cf6c1
# Name: cdtn_id, dtype: object       NaN       NaN
# 127                                                                                https://code.travail.gouv.fr/fiche-service-public/jour-ferie-pendant-les-conges-dun-salarie-quelles-sont-les-regles  13228    77e7059142
# Name: cdtn_id, dtype: object       NaN       NaN
# 128                                                                                                                                               https://code.travail.gouv.fr/code-du-travail/r3124-5   9723    6b964c827f
# Name: cdtn_id, dtype: object       NaN       NaN
# 129                                                                               https://code.travail.gouv.fr/fiche-ministere-travail/les-droits-et-obligations-des-salaries-du-particulier-employeur   1476    7fc9a530e6
# Name: cdtn_id, dtype: object       NaN       NaN
# 130                                                                                https://code.travail.gouv.fr/fiche-service-public/reduction-generale-des-cotisations-patronales-ex-reduction-fillon  13517    b49080a89a
# Name: cdtn_id, dtype: object       NaN       NaN
# 131                                                                        https://code.travail.gouv.fr/fiche-service-public/un-salarie-peut-il-faire-plusieurs-periodes-dessai-chez-le-meme-employeur  13205    5be88fb598
# Name: cdtn_id, dtype: object       NaN       NaN
# 132                                                                                                    https://code.travail.gouv.fr/fiche-service-public/quest-ce-que-le-cdi-intermittent-cdii-ou-cd2i  13122    8360662574
# Name: cdtn_id, dtype: object       NaN       NaN
# 133                                                                      https://code.travail.gouv.fr/fiche-service-public/quelles-sont-les-heures-dautorisation-de-sortie-du-salarie-en-arret-maladie  13258    5870600ea0
# Name: cdtn_id, dtype: object       NaN       NaN
# 134                                                                                    https://code.travail.gouv.fr/fiche-service-public/quest-ce-que-la-mobilite-volontaire-securisee-pour-un-salarie  13136    ec71237174
# Name: cdtn_id, dtype: object       NaN       NaN
# 135                                                                                           https://code.travail.gouv.fr/fiche-service-public/animation-quest-ce-que-le-contrat-dengagement-educatif  13487    142eae8aee
# Name: cdtn_id, dtype: object       NaN       NaN
# 136                                                                                                                                              https://code.travail.gouv.fr/code-du-travail/l3132-15   3810    16985ad815
# Name: cdtn_id, dtype: object       NaN       NaN
# 137                                      https://code.travail.gouv.fr/fiche-service-public/conge-de-3-jours-pour-la-naissance-ou-pour-larrivee-dun-enfant-en-vue-de-son-adoption-dans-le-secteur-prive  13354    5afee1b12a
# Name: cdtn_id, dtype: object       NaN       NaN
# 138                                                                                           https://code.travail.gouv.fr/fiche-service-public/autorisation-de-travail-dun-etranger-salarie-en-france  13107    9875d88809
# Name: cdtn_id, dtype: object       NaN       NaN
# 139                                                                                                             https://code.travail.gouv.fr/fiche-service-public/demission-dune-assistante-maternelle  13292    38474d168c
# Name: cdtn_id, dtype: object       NaN       NaN
# 140                                                                                                                                               https://code.travail.gouv.fr/code-du-travail/l4142-4  11315    f43de7b724
# Name: cdtn_id, dtype: object       NaN       NaN
# 141  https://code.travail.gouv.fr/information/informations-principales-sur-la-relation-de-travail-a-partir-du-1er-novembre-2023-quels-elements-doit-fournir-lemployeur-au-salarie-lors-de-son-embauche   1251    d77c8c5155
# Name: cdtn_id, dtype: object       NaN       NaN
# 142                                                                                                                                              https://code.travail.gouv.fr/code-du-travail/r3121-30   9861    388865144d
# Name: cdtn_id, dtype: object       NaN       NaN
# 143                                                                                                                                               https://code.travail.gouv.fr/code-du-travail/r4431-1   7920    e21383949d
# Name: cdtn_id, dtype: object       NaN       NaN
# 144                                                                         https://code.travail.gouv.fr/fiche-service-public/retraite-vivant-a-letranger-quand-faut-il-presenter-un-certificat-de-vie  13156    474ab30567
# Name: cdtn_id, dtype: object       NaN       NaN
# 145                                                                                                                            https://code.travail.gouv.fr/fiche-ministere-travail/le-conge-dadoption   1367    fc939ca0ac
# Name: cdtn_id, dtype: object       NaN       NaN
# 146                                                              https://code.travail.gouv.fr/fiche-service-public/un-interimaire-a-t-il-droit-a-un-conge-pour-un-projet-de-transition-professionnelle  13455    a05ae389e6
# Name: cdtn_id, dtype: object       NaN       NaN
# 147                                                                                   https://code.travail.gouv.fr/fiche-service-public/particulier-employeur-contrat-de-travail-du-salarie-a-domicile  13316    aba832128b
# Name: cdtn_id, dtype: object       NaN       NaN
# 148                                                                             https://code.travail.gouv.fr/fiche-service-public/contrat-de-travail-et-formalites-dembauche-de-lassistante-maternelle  13348    a38efb9268
# Name: cdtn_id, dtype: object       NaN       NaN
# 149                                                                                            https://code.travail.gouv.fr/fiche-service-public/sanctions-disciplinaires-dun-salarie-du-secteur-prive  13062    773df55d2f
# Name: cdtn_id, dtype: object       NaN       NaN

# %%
#1 run evaluation with current search (BGE M3) - deal with article + test rerank et full content

#2 run evaluation with BM25 / Hybrid search 

#3 bonus : run BGE M3 with dense / sparse / ColBert

# %%
results = {}
reports = []

max_gen = 13

async def run_search_analysis(i) :
    print(f"Question {i}")
    df = await analyze_question(i)
    
    #with pd.option_context('display.width', 500, 'display.max_rows', 150, 'display.max_colwidth', 200):
    #    display(df[["element", "in_results", "in_positives", "in_negatives", "reranked"]])
    TP = (df['in_results'] & df['in_positives']).sum()
    P = df['in_positives'].sum()
    #print(f"found : {TP} / {P}")

    # print last in search (to adapt top_k and score)
    last_idx_positive = df[(df['in_positives'] == 1) & (df['in_results'] == 1)].index.max()
    last_idx_positive_rr = df[(df['in_positives'] == 1) & (df['in_results'] == 1)]["reranked"].max()

    TP_rr = df[(df["reranked"] < max_gen) & (df["in_positives"] == 1)].shape[0]
    
    report = {
        "index": i, 
        "question": questions.loc[i]['question'],
        "n_positive": P,
        "last_idx_positive": last_idx_positive,
        "true_positives": TP,
        
        "recall": f"{TP/P:.3f}",
        "last_idx_positive_rr": last_idx_positive_rr,
    
        f"true_positives_rr_{max_gen}": TP_rr,
        f"recall_rr_{max_gen}": f"{TP_rr/P:.3f}",        
    }

    return report, df

for i in [6,8,11,14,15]:
    report, result = await run_search_analysis(i)
    results[i] = result;
    reports.append(report);

reports_df = pd.DataFrame(reports)
reports_df.set_index("index", inplace=True)
# Out:
# Question 6
# Bonjour,  J’ai effectuée un remplacement en CDD dans une micro crèche, mon contrat étant fini depuis le 22 septembre 2023 je suis toujours en attente de mon salaire. Après plusieurs relance auprès de la directrice aucun versement n’a été fait. J’aimerais savoir si elle est en droit de me faire patienter comme cela ou sinon qu’elle sont les délais pour qu’elle puisse me verser mon salaire. Cordialement,
# Question 8
# Bonjour,
# Actuellement membre du CSE, de la CSSCT et RPX, ma direction souhaite me
# changer de roulement à compter de janvier.
# Lors de notre première rencontre non officielle, il a été dit que mes
# absences mettaient mes collègues en souffrance dû au grand nombre de
# remplaçants et que sur l'équipe inverse elle doit séparer un binôme.
# Lors d'une seconde rencontre non officielle également, elle me dit qu'il
# n'ont rien à reprocher à mon travail seulement que sur les 2 équipes ils
# faut redynamiser un peu et séparer toujours le binôme.
# Je travaille en roulement amplitude de 12h, 10h travaillées et 2h de pause.
# 1 week-end sur 2, si elle me change, je travaillerais complètement à
# l'inverse de mon roulement actuel et donc mon mode de garde de mon enfant
# ne sera plus possible, par conséquent je risque de ne plus pouvoir venir
# travailler.
# Elle souhaite un changement début janvier, mais a ce jour je 'n'ai qu'un
# information officieuse, aucun entretien/courrier officiel
# J'ai un doute sur la réelle raison de ce changement, en tant que "salariée"
# protégée, a-t-elle le droit de me modifier mon roulement ?
# Je souhaite ses infos pour lui expliquer cela, avant de devoir faire des
# démarches plus poussées auprès des services compétents.
# Merci d'avance pour votre retour
#
# Question 11
# Bonjour je suis actuellement en conflit avec mon employeur qui ne m'a pas
# versé en intégralité les ijss que lui a versé la sécurité sociale, l
# entreprise à subrogation, es que vous avez un moyen de pression si je peux
# dire pour que la situation ce debloque merci
#
# Question 14
# Quelle est la procdure suivre pour demander une dérogation pour que mes techniciens puissent ponctuellement travailler 60 heures par semaine pour un chantier particulier?
#
# Cest dire rajouter la journée du samedi au reste de la semaine.
# Question 15
# Bonjour, Mon employeur m'a employée en CDI mais ne m'a pas fait signer de contrat de travail. J'ai démarré en mai et j'ai bien eu 2 fiches de paie pour mai et juin. Sans contrat de travail, est-ce que cela signifie que par défaut je n'ai pas de période d'essai ? Merci par avance,

# %%
# report standard
reports_df
# Out:
#                                                 question  n_positive  \
# index
# 6      Bonjour,  J’ai effectuée un remplacement en CD...           4
# 8      Bonjour,\nActuellement membre du CSE, de la CS...          14
# 11     Bonjour je suis actuellement en conflit avec m...           4
# 14     Quelle est la procdure suivre pour demander un...           2
# 15     Bonjour, Mon employeur m'a employée en CDI mai...           5
#
#        last_idx_positive  true_positives recall  last_idx_positive_rr  \
# index
# 6                     65               4  1.000                  30.0
# 8                     62              14  1.000                  59.0
# 11                    58               4  1.000                  19.0
# 14                    29               2  1.000                   3.0
# 15                    27               5  1.000                  15.0
#
#        true_positives_rr_10 recall_rr_10
# index
# 6                         1        0.250
# 8                         8        0.571
# 11                        3        0.750
# 14                        2        1.000
# 15                        4        0.800

# %%
# report MB25 only
reports_df
# Out:
#                                                 question  n_positive  \
# index
# 6      Bonjour,  J’ai effectuée un remplacement en CD...           4
# 8      Bonjour,\nActuellement membre du CSE, de la CS...          14
# 11     Bonjour je suis actuellement en conflit avec m...           4
# 14     Quelle est la procdure suivre pour demander un...           2
# 15     Bonjour, Mon employeur m'a employée en CDI mai...           5
#
#        last_idx_positive  true_positives recall  last_idx_positive_rr  \
# index
# 6                     71               4  1.000                  12.0
# 8                    103               8  0.571                  31.0
# 11                   112               3  0.750                   4.0
# 14                    69               2  1.000                   2.0
# 15                    75               5  1.000                   8.0
#
#        true_positives_rr_10 recall_rr_10
# index
# 6                         2        0.500
# 8                         3        0.214
# 11                        1        0.250
# 14                        1        0.500
# 15                        4        0.800

# %%
# report both
reports_df
# Out:
#                                                 question  n_positive  \
# index
# 6      Bonjour,  J’ai effectuée un remplacement en CD...           4
# 8      Bonjour,\nActuellement membre du CSE, de la CS...          14
# 11     Bonjour je suis actuellement en conflit avec m...           4
# 14     Quelle est la procdure suivre pour demander un...           2
# 15     Bonjour, Mon employeur m'a employée en CDI mai...           5
#
#        last_idx_positive  true_positives recall  last_idx_positive_rr  \
# index
# 6                     33               4  1.000                  26.0
# 8                    111              14  1.000                  40.0
# 11                    90               4  1.000                   6.0
# 14                    13               2  1.000                   3.0
# 15                     9               5  1.000                  12.0
#
#        true_positives_rr_13 recall_rr_13
# index
# 6                         1        0.250
# 8                         8        0.571
# 11                        3        0.750
# 14                        2        1.000
# 15                        5        1.000

# %%
from retriv import SearchEngine
import spacy
nlp_fr = spacy.load('fr_core_news_md')

docs = pd.read_parquet("/Users/remi/tmp/docs_prepro.parquet")
# remove CCs
docs = docs[docs['idcc'].isnull() | (docs['idcc'] == '0000')]

collection = docs[["cdtn_id", "prepro"]].rename(columns={'cdtn_id': 'id', 'prepro': 'text'}).to_dict(orient='records')

se = SearchEngine("new-index", stemmer=None, stopwords=None, min_df=2,).index(collection)
# Out:
# /Users/remi/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/spacy/util.py:910: UserWarning: [W095] Model 'fr_core_news_md' (3.8.0) was trained with spaCy v3.8.0 and may not be 100% compatible with the current version (3.7.5). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Building TDF matrix: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12359/12359 [00:02<00:00, 4144.78it/s]
# Building inverted index: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12048/12048 [00:00<00:00, 24306.78it/s]

# %%
def preprocess(chunks):
    fulltext = " ".join(chunks)
    tokens = nlp_fr(fulltext)
    res = []
    for token in tokens:        
        if not token.is_punct and not token.is_space:
            res.append(token.lemma_)
    return " ".join(res)

def postprocess(result):
    doc = docs[docs['cdtn_id'] == result['id']].to_dict(orient='records')[0]    
    return {"chunk":{"metadata":{"url": doc["url"], "id": doc["cdtn_id"]}, "content": " ".join(doc["content_chunked"])}, "score":result["score"]}    

    
def search_bm25(query):
    q_prepro = preprocess([query])
    res = se.search(q_prepro, cutoff=120)
    
    chunks = [postprocess(r) for r in res]
    return chunks

# %%
search_bm25(questions.loc[14]['question'])[0]
# Out:
# {'chunk': {'metadata': {'url': 'https://code.travail.gouv.fr/fiche-service-public/duree-du-travail-dun-salarie-a-temps-plein',
#    'id': 'abdd8263ba'},
#   'content': "Combien d'heures de travail pouvez-vous effectuer par jour, par semaine, par mois et par an ? Est-il possible de travailler plus longtemps que la durée légale le prévoit ? Nous vous expliquons vos droits et vos obligations concernant la durée du temps de travail. Quelle est la durée légale de temps de travail ? La durée légale de temps de travail dépend de votre situation. Cas général La durée légale du travail pour un temps complet est fixée à : 35 heures par semaine 151,67 heures par mois 1 607 heures par an Cependant, des dispositions conventionnelles peuvent prévoir une durée de travail hebdomadaire supérieure ou inférieure à 35 heures. Les heures effectuées au-delà de la durée légale sont considérées comme des heures supplémentaires . Vous êtes cadre dirigeant En tant que cadre dirigeant, vous n'avez pas à respecter une durée de temps de travail, minimale ou maximale. Pour être considéré comme cadre dirigeant, vous devez cumuler les 3 critères suivants : Vous voir confier des responsabilités dont l'importance implique une grande indépendance dans l'organisation de votre emploi du temps Être habilité à prendre des décisions de façon largement autonome Avoir une rémunération se situant dans les niveaux les plus élevés des systèmes de rémunération pratiqués dans l'entreprise Vous êtes salarié ou apprenti âgé de moins de 18 ans Votre temps de travail est conditionné à des dispositions spécifiques . Quelle est la durée quotidienne maximale de temps de travail ? La durée de votre travail effectif ne doit pas dépasser la durée maximale de 10 heures . Cependant, des dérogations sont accordées dans les cas suivants : À la demande de votre employeur qui doit de plus demander l'accord de l'inspecteur du travail En cas d'urgence liée à un surcroît temporaire d'activité Si une convention collective le prévoit. En cas d'activité accrue ou pour des motifs liés à l'organisation de l'entreprise, la durée maximale quotidienne de travail est limitée à 12 heures par jour de travail effectif. Quelle est la durée maximale de temps de travail hebdomadaire ? La durée de travail effectif hebdomadaire ne doit pas dépasser les 2 limites suivantes : 48 heures sur une même semaine 44 heures par semaine en moyenne sur une période de 12 semaines consécutives. Exemple Si vous êtes amené à travailler 48 heures hebdomadaires pendant 6 semaines d'affilée, puis 40 heures les 6 semaines suivantes, vous aurez alors travaillé en moyenne 44 heures hebdomadaires sur la période de 12 semaines consécutives. Votre temps de travail ne dépasse donc pas les durées maximales hebdomadaires de travail autorisées. Par dérogation, la durée maximale sur une semaine peut être augmentée, en cas de circonstances exceptionnelles, jusqu'à 60 heures maximum. Pour cela, l'inspection du travail doit donner son accord. Le dépassement de la durée moyenne de 44 heures est possible, dans la limite de 46 heures sur une période de 12 semaines consécutives, dans l'un des cas suivants : Une convention collective ou un accord collectif d'entreprise le prévoit Après autorisation de l'inspection du travail Quels sont les temps de pauses prévus ? Un temps de pause d'au moins 20 minutes consécutives vous est accordé, dès que vous avez travaillé 6 heures consécutives. La pause est accordée soit immédiatement après 6 heures de travail, soit avant que cette durée de 6 heures ne soit entièrement écoulée. À savoir le temps du déjeuner, qui s'intercale entre 2 périodes de travail effectif, est considéré comme un temps de pause. Comment sont décomptées les heures de travail ? Votre employeur peut mettre en place des horaires collectifs de travail s'appliquant à l'ensemble des salariés de l'entreprise. Un dispositif d'horaires individualisés peut également vous être proposé, sous conditions. Vous travaillez en horaires collectifs En cas d'horaires collectifs, votr ...
#  'score': 38.156403}

# %%
results_albert = collections.search(questions.loc[14]['question'], [contributions_col, info_col, fiche_mt_col, fiche_sp_col], 128)
results_albert[0]
# Out:
# {'method': 'semantic',
#  'score': 0.69506603,
#  'chunk': {'object': 'chunk',
#   'id': 1,
#   'metadata': {'id': 'b9c2c2f2f1',
#    'url': 'https://code.travail.gouv.fr/fiche-ministere-travail/le-travail-du-dimanche',
#    'source': 'page_fiche_ministere_travail',
#    'title': 'Le travail du dimanche',
#    'collection_id': 735,
#    'document_id': 746753,
amené à travailler 48 heures hebdomadaires pendant 6 semaines d'affilée, puis 40 heures les 6 semaines suivantes, vous aurez alors travaillé en moyenne 44 heures hebdomadaires sur la période de 12 semaines consécutives. Votre temps de travail ne dépasse donc pas les durées maximales hebdomadaires de travail autorisées. Par dérogation, la durée maximale sur une semaine peut être augmentée, en cas de circonstances exceptionnelles, jusqu'à 60 heures maximum. Pour cela, l'inspection du travail doit donner son accord. Le dépassement de la durée moyenne de 44 heures est possible, dans la limite de 46 heures sur une période de 12 semaines consécutives, dans l'un des cas suivants : Une convention collective ou un accord collectif d'entreprise le prévoit Après autorisation de l'inspection du travail Quels sont les temps de pauses prévus ? Un temps de pause d'au moins 20 minutes consécutives vous est accordé, dès que vous avez travaillé 6 heures consécutives. La pause est accordée soit immédiatement après 6 heures de travail, soit avant que cette durée de 6 heures ne soit entièrement écoulée. À savoir le temps du déjeuner, qui s'intercale entre 2 périodes de travail effectif, est considéré comme un temps de pause. Comment sont décomptées les heures de travail ? Votre employeur peut mettre en place des horaires collectifs de travail s'appliquant à l'ensemble des salariés de l'entreprise. Un dispositif d'horaires individualisés peut également vous être proposé, sous conditions. Vous travaillez en horaires collectifs En cas d'horaires collectifs, votr ...
#  'score': 35.702667}

# %%
chunk['metadata']['url']
    content = chunk['content']
    score = f'{chunk['score']

# %%
run_dict = {
    "q_1": {
        "d_12": 0.9,
        "d_23": 0.8,
        "d_25": 0.7,
        "d_36": 0.6,
        "d_32": 0.5,
        "d_35": 0.4,
    },
    "q_2": {
        "d_12": 0.9,
        "d_11": 0.8,
        "d_25": 0.7,
        "d_36": 0.6,
        "d_22": 0.5,
        "d_35": 0.4,
    },
}

# %%
from ranx import fuse, Run

# todo deal with multiple matches
formatted_albert = {c['chunk']["metadata"]["id"]:c["score"] for c in results_albert}
run_albert = Run({"14" : formatted_albert})

# %%
formatted_bm25 = {c['chunk']["metadata"]["id"]:c["score"] for c in results_bm25}
run_bm25 = Run({"14" : formatted_bm25})

# %%
formatted_albert
# Out:
# {'b9c2c2f2f1': 0.57793665,
#  '57a22d7a6c': 0.5952884,
#  '72a440e404': 0.5988307,
#  'd094601132': 0.5935703,
#  '7bd7e2ee64': 0.5889483,
#  '1e9dda80aa': 0.57754314,
#  'd8131643b9': 0.5735023,
#  '30fbfc0fc5': 0.59308183,
#  '49353eade2': 0.5797432,
#  'be4ca37b56': 0.57327914,
#  '617a4e4045': 0.5821527,
#  '343af01e28': 0.5867203,
#  'fd362898df': 0.61112905,
#  '8a1c8b5007': 0.60900664,
#  'f6e73ca640': 0.57420266,
#  'ef70331d5f': 0.6060802,
#  'baf42db024': 0.59876263,
#  '394e25d76c': 0.58594126,
#  '51afbbbe4e': 0.5985574,
#  'e3c27df0bb': 0.58070487,
#  '9045a08044': 0.5982444,
#  'f81be1df7e': 0.5841069,
#  '15fc023268': 0.57593346,
#  '6b800529ea': 0.58895075,
#  '1f63bfcedf': 0.59257805,
#  '195bc00ae8': 0.5913188,
#  'ba22bf2ee7': 0.59099066,
#  '3a8e55b1dd': 0.5907236,
#  'bce90c20a4': 0.008928571428571428,
#  '889584bbec': 0.008849557522123894,
#  '1096c49ada': 0.008849557522123894,
#  '32ceeb6582': 0.008771929824561403,
#  '742007ad4a': 0.008695652173913044,
#  'f719b0488c': 0.008620689655172414,
#  '77583a28a2': 0.00847457627118644,
#  'aa509b739c': 0.008403361344537815,
#  '84ded19efe': 0.008333333333333333,
#  '4b11abc89d': 0.008264462809917356,
#  'a502802613': 0.00819672131147541,
#  'a7ef10ff8a': 0.008130081300813009,
#  'fa626391e7': 0.008064516129032258,
#  '7ad2822b65': 0.008,
#  '9e4cb6496c': 0.007936507936507936,
#  '1cd72377cc': 0.007874015748031496,
#  'b677974ade': 0.0078125,
#  '38c3cccdec': 0.007751937984496124,
#  '4a80ea3704': 0.007692307692307693,
#  'cf11049752': 0.007633587786259542,
#  '6a9c0f759c': 0.007575757575757576,
#  '44bf5ecd56': 0.007518796992481203,
#  '57dc3b102e': 0.007462686567164179,
#  'e6905932ab': 0.007407407407407408,
#  '8d99ec29e1': 0.007352941176470588,
#  '2d4ad36de2': 0.0072992700729927005,
#  '65c9f44269': 0.007246376811594203,
#  'a04cc37290': 0.007194244604316547,
#  '4f63b0fa5d': 0.007142857142857143,
#  'd902521d96': 0.0070921985815602835,
#  'c06277e8e8': 0.007042253521126761,
#  '85a1924cb9': 0.006944444444444444,
#  'f9cf75e110': 0.006896551724137931,
#  '8130c51d06': 0.00684931506849315,
#  'eac3c3bad7': 0.006802721088435374,
#  'b168bd125b': 0.006756756756756757,
#  '1a544a78f3': 0.006711409395973154,
#  '9642731b47': 0.006666666666666667,
#  'f5438bd6df': 0.006622516556291391,
#  '1e2480100e': 0.006578947368421052,
#  '3a9d75daba': 0.006535947712418301,
#  'a6fdbb4358': 0.006493506493506494,
#  'a5d7768246': 0.0064516129032258064,
#  '7c67504a9e': 0.00641025641025641,
#  '48119a9d8d': 0.006369426751592357,
#  '82edbbaa8d': 0.006289308176100629,
#  'f9f674b102': 0.00625,
#  'a7e6ecc28e': 0.006211180124223602,
#  '9b240ddc20': 0.006172839506172839,
#  '96c18d9532': 0.006060606060606061,
#  'dab79cc075': 0.006024096385542169,
#  '799ae8f18b': 0.005988023952095809,
#  '26045c726d': 0.005952380952380952,
#  '1bfad1c982': 0.005917159763313609,
#  '35b2cc378a': 0.0058823529411764705,
#  'dc14459b20': 0.005847953216374269,
#  'e5ccee590d': 0.005813953488372093,
#  '1bfbf4186f': 0.005780346820809248,
#  'aa3775f94a': 0.005747126436781609,
#  'dc97d06eb3': 0.005714285714285714,
#  '5f1c8bf4ef': 0.005681818181818182,
#  '4e0dedaa2e': 0.005649717514124294,
#  'e1599c3a6d': 0.0056179775280898875,
#  '81f04c2745': 0.00558659217877095,
#  'c7bacb2e85': 0.005555555555555556}

# %%
from ranx import fuse, Run

def row_to_chunk(cdtn_id, score):    
    doc = docs[docs['cdtn_id'] == cdtn_id].to_dict(orient='records')[0]    
    return {"score": score, "chunk":{"metadata":{"url": doc["url"], "id": doc["cdtn_id"]}, "content": " ".join(doc["content_chunked"])}, "n_chunks":len(doc["content_chunked"])}    

def combined_search(query):
    k = "q"
    
    results_albert = collections.search(query, [contributions_col, info_col, fiche_mt_col, fiche_sp_col], 128)
    formatted_albert = {c['chunk']["metadata"]["id"]:c["score"] for c in results_albert}
    run_albert = Run({k : formatted_albert})
    
    results_bm25 = search_bm25(query)
    formatted_bm25 = {c['chunk']["metadata"]["id"]:c["score"] for c in results_bm25}
    run_bm25 = Run({k : formatted_bm25})

    combined_test_run = fuse(
        runs=[run_albert, run_bm25],  
        norm="min-max",       
        method="rrf"        
    )

    return [row_to_chunk(id, score) for id, score in combined_test_run[k].items()]

# %%
question = "coucou"

# %%
from FlagEmbedding import BGEM3FlagModel
model = BGEM3FlagModel('BAAI/bge-m3', use_fp16=True)
# Out:
# Fetching 30 files:   0%|          | 0/30 [00:00<?, ?it/s]

# %%
model.encode([question], return_dense=True, return_sparse=True, return_colbert_vecs=True, max_length=1024)

# %%
docs['full_content'] = docs['content_chunked'].apply(lambda x: " /n ".join(x))

# %%
res = model.encode(docs['full_content'][0:200].tolist(), return_dense=True, return_sparse=False, return_colbert_vecs=False, max_length=1024)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 res = model.encode(docs['full_content'][0:200].tolist(), return_dense=True, return_sparse=False, return_colbert_vecs=False, max_length=1024)
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/FlagEmbedding/inference/embedder/encoder_only/m3.py:295, in M3Embedder.encode(self, sentences, batch_size, max_length, return_dense, return_sparse, return_colbert_vecs, **kwargs)
#     292 if return_sparse is None: return_sparse = self.return_sparse
#     293 if return_colbert_vecs is None: return_colbert_vecs = self.return_colbert_vecs
# --> 295 return super().encode(
#     296     sentences,
#     297     batch_size=batch_size,
#     298     max_length=max_length,
#     299     return_dense=return_dense,
#     300     return_sparse=return_sparse,
#     301     return_colbert_vecs=return_colbert_vecs,
#     302     **kwargs
#     303 )
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/FlagEmbedding/abc/inference/AbsEmbedder.py:266, in AbsEmbedder.encode(self, sentences, batch_size, max_length, convert_to_numpy, instruction, instruction_format, **kwargs)
#     262         sentences = [self.get_detailed_instruct(instruction_format, instruction, sentence) for sentence in
#     263                      sentences]
#     265 if isinstance(sentences, str) or len(self.target_devices) == 1:
# --> 266     return self.encode_single_device(
#     267         sentences,
#     268         batch_size=batch_size,
#     269         max_length=max_length,
#     270         convert_to_numpy=convert_to_numpy,
#     271         device=self.target_devices[0],
#     272         **kwargs
#     273     )
#     275 if self.pool is None:
#     276     self.pool = self.start_multi_process_pool(AbsEmbedder._encode_multi_process_worker)
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/FlagEmbedding/inference/embedder/encoder_only/m3.py:400, in M3Embedder.encode_single_device(self, sentences, batch_size, max_length, return_dense, return_sparse, return_colbert_vecs, device, **kwargs)
#     393 try:
#     394     inputs_batch = self.tokenizer.pad(
#     395         all_inputs_sorted[: batch_size],
#     396         padding=True,
#     397         return_tensors='pt',
#     398         **kwargs
#     399     ).to(device)
# --> 400     outputs = self.model(
#     401         inputs_batch,
#     402         return_dense=return_dense,
#     403         return_sparse=return_sparse,
#     404         return_colbert_vecs=return_colbert_vecs
#     405     )
#     406     flag = True
#     407 except RuntimeError as e:
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/FlagEmbedding/finetune/embedder/encoder_only/m3/modeling.py:547, in EncoderOnlyEmbedderM3ModelForInference.forward(self, text_input, return_dense, return_sparse, return_colbert_vecs, return_sparse_embedding)
#     543 # this is for sparse embedding computation: using optimization suggestion from
#     544 # issue #1364: https://github.com/FlagOpen/FlagEmbedding/issues/1364
#     545 self.training = False
# --> 547 last_hidden_state = self.model(**text_input, return_dict=True).last_hidden_state
#     549 output = {}
#     550 if return_dense:
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:849, in XLMRobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     842 # Prepare head mask if needed
#     843 # 1.0 in head_mask indicate we keep the head
#     844 # attention_probs has shape bsz x n_heads x N x N
#     845 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#     846 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#     847 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# --> 849 encoder_outputs = self.encoder(
#     850     embedding_output,
#     851     attention_mask=extended_attention_mask,
#     852     head_mask=head_mask,
#     853     encoder_hidden_states=encoder_hidden_states,
#     854     encoder_attention_mask=encoder_extended_attention_mask,
#     855     past_key_values=past_key_values,
#     856     use_cache=use_cache,
#     857     output_attentions=output_attentions,
#     858     output_hidden_states=output_hidden_states,
#     859     return_dict=return_dict,
#     860 )
#     861 sequence_output = encoder_outputs[0]
#     862 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:608, in XLMRobertaEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     605 layer_head_mask = head_mask[i] if head_mask is not None else None
#     606 past_key_value = past_key_values[i] if past_key_values is not None else None
# --> 608 layer_outputs = layer_module(
#     609     hidden_states,
#     610     attention_mask,
#     611     layer_head_mask,
#     612     encoder_hidden_states,  # as a positional argument for gradient checkpointing
#     613     encoder_attention_mask=encoder_attention_mask,
#     614     past_key_value=past_key_value,
#     615     output_attentions=output_attentions,
#     616 )
#     618 hidden_states = layer_outputs[0]
#     619 if use_cache:
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/transformers/modeling_layers.py:83, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      80         logger.warning(message)
#      82     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 83 return super().__call__(*args, **kwargs)
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:551, in XLMRobertaLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     548     cross_attn_present_key_value = cross_attention_outputs[-1]
#     549     present_key_value = present_key_value + cross_attn_present_key_value
# --> 551 layer_output = apply_chunking_to_forward(
#     552     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     553 )
#     554 outputs = (layer_output,) + outputs
#     556 # if decoder, return the attn key/values as the last output
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/transformers/pytorch_utils.py:250, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     247     # concatenate output at same dimension
#     248     return torch.cat(output_chunks, dim=chunk_dim)
# --> 250 return forward_fn(*input_tensors)
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:563, in XLMRobertaLayer.feed_forward_chunk(self, attention_output)
#     562 def feed_forward_chunk(self, attention_output):
# --> 563     intermediate_output = self.intermediate(attention_output)
#     564     layer_output = self.output(intermediate_output, attention_output)
#     565     return layer_output
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:462, in XLMRobertaIntermediate.forward(self, hidden_states)
#     460 def forward(self, hidden_states: torch.Tensor) -> torch.Tensor:
#     461     hidden_states = self.dense(hidden_states)
# --> 462     hidden_states = self.intermediate_act_fn(hidden_states)
#     463     return hidden_states
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.12.10/envs/play/lib/python3.12/site-packages/transformers/activations.py:69, in GELUActivation.forward(self, input)
#      68 def forward(self, input: Tensor) -> Tensor:
# ---> 69     return self.act(input)
#
# KeyboardInterrupt:

# %%
res['dense_vecs'].shape
# Out:
# (2, 1024)
